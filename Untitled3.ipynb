# %%
import os
import sys
import pandas as pd
import re
import nltk
import emoji
import pickle
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# C:\Users\wisnu\AppData\Local\Temp\ipykernel_7384\540588830.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From C:\Users\wisnu\tugas_akhir\tugas_akhir\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#       Unnamed: 0     label                                              tweet
# 0              0  Positive  im getting on borderlands and i will murder yo...
# 1              1  Positive  I am coming to the borders and I will kill you...
# 2              2  Positive  im getting on borderlands and i will kill you ...
# 3              3  Positive  im coming on borderlands and i will murder you...
# 4              4  Positive  im getting on borderlands 2 and i will murder ...
# ...          ...       ...                                                ...
# 5557       10093  Negative  Microsoft could, of course, do a better job de...
# 5558       10094  Negative  Microsoft, of course, could do a better job of...
# 5559       10095  Negative  Microsoft could of done an better job of demon...
# 5560       10096  Negative  Now Microsoft could of had done a better job o...
# 5561       10097  Negative  Microsoft could of done a good job of improvin...
#
# [5562 rows x 3 columns]

# %%
# Handle Emoji
def demojize(tweet):
  tweet = emoji.demojize(tweet)
  return tweet
# Handle RT tag
def replace_retweet(tweet):
  tweet = re.sub(r'RT\\S+', '', tweet)
  return tweet

# Handle user tag
def replace_user(tweet, default_replace=""):
  tweet = re.sub('\\B@\\w+', default_replace, tweet)
  return tweet

# Handle URL
def replace_url(tweet):
  tweet = re.sub(r'http\\S+', '', tweet)
  return tweet

# Handle hashtag
def replace_hashtag(tweet, default_replace=""):
  tweet = re.sub('#+', default_replace, tweet)
  return tweet

# Word Features
# Handle case
def to_lowercase(tweet):
  tweet = tweet.lower()
  return tweet

# Handle word repetion
def word_repetition(tweet):
  tweet = re.sub(r'(.)\\1+', r'\\1\\1', tweet)
  return tweet

# Handle Punctuation repetition
def punct_repetition(tweet, default_replace=""):
  tweet = re.sub(r'[^\w\s]', default_replace, tweet)
  return tweet

# Stopwords removal
stop_words = set(stopwords.words('english'))
# function to remove stopwords
def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    return ' '.join(no_stopword_text)

# Word lemmitization
lemmatizer = WordNetLemmatizer()
def lemmatization(text):
    lem = [lemmatizer.lemmatize(w) for w in text.split()]
    return ' '.join(lem)

# %%
def process_tweet(tweet, verbose=False):
  if verbose: print("Initial tweet: {}".format(tweet))

  ## Twitter Features
  tweet = replace_retweet(tweet) # replace retweet
  tweet = replace_user(tweet) # replace user tag
  tweet = replace_url(tweet) # replace url
  tweet = replace_hashtag(tweet) # replace hashtag
  tweet = demojize(tweet) # replace emoji
  if verbose: print("Post Twitter processing tweet: {}".format(tweet))

  ## Word Features
  tweet = to_lowercase(tweet) # replace wordcase
  tweet = punct_repetition(tweet) # replace punctuation repetition
  tweet = word_repetition(tweet) # replace word repetition\
  tweet = remove_stopwords(tweet) # stopword removal
  tweet = lemmatization(tweet) # word lemmitization
  if verbose: print("Post Word processing tweet: {}".format(tweet))

  return tweet

# %%
tweet_id = 1006
sampletweet = df.iloc[tweet_id]
test_text = sampletweet['tweet']
print(process_tweet(test_text, verbose=False))
# Out:
# game hardware doesnt register right way sometimes ammo regen weapon isnt always working properly sometimes entire bullet donat register hit enemy fix soon plssssss

# %%
df['tweet'] = df['tweet'].apply(str)
df['tweet'] = df['tweet'].apply(process_tweet)
df
# Out:
#       Unnamed: 0     label                                              tweet
# 0              0  Positive                       im getting borderland murder
# 1              1  Positive                                 coming border kill
# 2              2  Positive                         im getting borderland kill
# 3              3  Positive                        im coming borderland murder
# 4              4  Positive                     im getting borderland 2 murder
# ...          ...       ...                                                ...
# 5557       10093  Negative  microsoft could course better job demonstratin...
# 5558       10094  Negative  microsoft course could better job demonstratin...
# 5559       10095  Negative  microsoft could done better job demonstrating ...
# 5560       10096  Negative  microsoft could done better job demonstrating ...
# 5561       10097  Negative  microsoft could done good job improving gamepl...
#
# [5562 rows x 3 columns]

# %%
print("Shape of X:", len(texts))
print("Length of labels:", len(labels))
# Out:
# Shape of X: 43012
# Length of labels: 43012

# %%
# Feature extraction
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['tweet'])

# %%
print("Shape of X after vectorization:", X.shape)
# Out:
# Shape of X after vectorization: (5562, 5384)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df['label'], test_size=0.2)

# %%
svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
predictions = svm_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.945193171608266

# %%
conf_mat = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=['Negative', 'Positive'])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
def check_finite(data):
    if not np.all(np.isfinite(data)):
        raise ValueError("Data contains non-finite values (NaN, inf, -inf)")

check_finite(X_train.toarray())
check_finite(X_test.toarray())

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.toarray())
X_test_scaled = scaler.transform(X_test.toarray())

# %%
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
svm_model_pca = SVC(kernel='linear', probability=True)
svm_model_pca.fit(X_train_pca, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
h = .02  # step size in the mesh
x_min, x_max = X_train_pca[:, 0].min() - 1, X_train_pca[:, 0].max() + 1
y_min, y_max = X_train_pca[:, 1].min() - 1, X_train_pca[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# %%
Z = svm_model_pca.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], c=y_test, cmap=plt.cm.coolwarm, edgecolors='k')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('SVM Decision Boundary with PCA-reduced TF-IDF Features')
plt.show()

# %%
pickle.dump(svm_model, open("sentiment_analysis_model.pkl", "wb"))

# %%
pickle.dump(vectorizer, open("vectorizer.pkl", "wb"))
